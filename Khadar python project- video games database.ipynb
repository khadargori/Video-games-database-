# %%
import pandas as pd
import matplotlib.pyplot as mplt
video_games = pd.read_csv("Video_Games1.csv")
video_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#1. get sample of any 5 rows.
print("1. sample of 5 rows:")
video_games.sample(5)
# Out:
# 1. sample of 5 rows:
#                               Name Platform  Year_of_Release     Genre  \
# 2696                FIFA Soccer 11      PS2           2010.0    Sports
# 3522                      WWE 2K15     XOne           2014.0    Sports
# 2790  Dragon Ball Z: Ultime Menace     SNES           1993.0  Fighting
# 2969        Test Drive Unlimited 2     X360              NaN    Racing
# 1739         Mario vs. Donkey Kong      GBA           2004.0    Puzzle
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2696       Electronic Arts      0.11      0.29      0.00         0.36
# 3522  Take-Two Interactive      0.29      0.23      0.00         0.05
# 2790    Namco Bandai Games      0.00      0.00      0.73         0.00
# 2969                 Atari      0.30      0.31      0.00         0.07
# 1739              Nintendo      0.68      0.25      0.21         0.02
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %%
#2. display all the columns in the dataset.
print("2. all columns in the dataset:")
video_games.columns
# Out:
# 2. all columns in the dataset:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
#3. display the dimensions.
print("3. Display the Dimensions")
video_games.shape
# Out:
# 3. Display the Dimensions
# (16719, 16)

# %%
#4. Display all the columns datatypes.
print("4. Display columns datatypes:")
video_games.dtypes
# Out:
# 4. Display columns datatypes:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#5. Display top 10 rows.
print("5. display top 10 rows:")
video_games.head(10)
# Out:
# 5. display top 10 rows:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
#6. display the bottom 10 rows.
print("6. Display the bottom 10 rows:")
video_games.tail(10)
# Out:
# 6. Display the bottom 10 rows:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# ...

# %%
#7. Display all racing games which have critic score >= 95.
print("7. all racing games which have critic score>=95:")
video_games[(video_games['Genre']=='Racing')&(video_games['Critic_Score']>=95)]
# Out:
# 7. all racing games which have critic score>=95:
#                       Name Platform  Year_of_Release   Genre  \
# 28  Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 52            Gran Turismo       PS           1997.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 52  Sony Computer Entertainment      4.02      3.87      2.54         0.52
#
#     Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 28         14.98          95.0          54.0        8.4       314.0
# 52         10.95          96.0          16.0        8.7       138.0
#
#             Developer Rating
# 28  Polyphony Digital      E
# 52  Polyphony Digital      E

# %%
#8. Display video games whose user_score >9.
print("video games whose user_score>9:")
video_games['User_Score']=pd.to_numeric(video_games['User_Score'],errors='coerce')
video_games[video_games['User_Score']>9]
# Out:
# video games whose user_score>9:
#                                             Name Platform  Year_of_Release  \
# 65                             Final Fantasy VII       PS           1997.0
# 97                          Super Mario Galaxy 2      Wii           2010.0
# 106                                     Tekken 3       PS           1998.0
# 110                                 Mario Kart 8     WiiU           2014.0
# 111                      Super Smash Bros. Melee       GC           2001.0
# ...                                          ...      ...              ...
# 16230                  Monster Rancher Advance 2      GBA           2002.0
# 16355                                    Deus Ex       PC           2000.0
# 16433  Greg Hastings' Tournament Paintball Max'd      PS2           2006.0
# 16550                Wade Hixton's Counter Punch      GBA           2004.0
# 16631                              Karnaaj Rally      GBA           2003.0
#
# ...

# %%
#9. Display all unique User Scores.
print("9. all unique User_Scores:")
print(video_games['User_Score'].unique())
# Out:
# 9. all unique User_Scores:
# [8.  nan 8.3 8.5 6.6 8.4 8.6 7.7 6.3 7.4 8.2 9.  7.9 8.1 8.7 7.1 3.4 5.3
#  4.8 3.2 8.9 6.4 7.8 7.5 2.6 7.2 9.2 7.  7.3 4.3 7.6 5.7 5.  9.1 6.5 8.8
#  6.9 9.4 6.8 6.1 6.7 5.4 4.  4.9 4.5 9.3 6.2 4.2 6.  3.7 4.1 5.8 5.6 5.5
#  4.4 4.6 5.9 3.9 3.1 2.9 5.2 3.3 4.7 5.1 3.5 2.5 1.9 3.  2.7 2.2 2.  9.5
#  2.1 3.6 2.8 1.8 3.8 0.  1.6 9.6 2.4 1.7 1.1 0.3 1.5 0.7 1.2 2.3 0.5 1.3
#  0.2 0.6 1.4 0.9 1.  9.7]

# %%
#10. Display all types of games.
print("all types of games:")
print(video_games['Genre'].unique())
# Out:
# all types of games:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' nan]

# %%
#11. Access row 15.
print("row 15:")
print(video_games.iloc[14])
# Out:
# row 15:
# Name                   Kinect Adventures!
# Platform                             X360
# Year_of_Release                    2010.0
# Genre                                Misc
# Publisher          Microsoft Game Studios
# NA_Sales                             15.0
# EU_Sales                             4.89
# JP_Sales                             0.24
# Other_Sales                          1.69
# Global_Sales                        21.81
# Critic_Score                         61.0
# Critic_Count                         45.0
# User_Score                            6.3
# User_Count                          106.0
# Developer             Good Science Studio
# Rating                                  E
# Name: 14, dtype: object

# %%
#12. Display EU_Sales,Global_Sales and Critic_Count.
print("EU_Sales,Global_Sales and Critic_Count:")
print(video_games.iloc[:,[6,9,11]])
# Out:
# EU_Sales,Global_Sales and Critic_Count:
#        EU_Sales  Global_Sales  Critic_Count
# 0         28.96         82.53          51.0
# 1          3.58         40.24           NaN
# 2         12.76         35.52          73.0
# 3         10.93         32.77          73.0
# 4          8.89         31.37           NaN
# ...         ...           ...           ...
# 16714      0.00          0.01           NaN
# 16715      0.01          0.01           NaN
# 16716      0.00          0.01           NaN
# 16717      0.00          0.01           NaN
# 16718      0.00          0.01           NaN
#
# [16719 rows x 3 columns]

# %%
#13. Display the name,Genre and Developer of all games using loc
print("13. Name,Genre,Developer:")
video_games.loc[:,['Name','Genre','Developer']]
# Out:
# 13. Name,Genre,Developer:
#                                 Name         Genre Developer
# 0                         Wii Sports        Sports  Nintendo
# 1                  Super Mario Bros.      Platform       NaN
# 2                     Mario Kart Wii        Racing  Nintendo
# 3                  Wii Sports Resort        Sports  Nintendo
# 4           Pokemon Red/Pokemon Blue  Role-Playing       NaN
# ...                              ...           ...       ...
# 16714  Samurai Warriors: Sanada Maru        Action       NaN
# 16715               LMA Manager 2007        Sports       NaN
# 16716        Haitaka no Psychedelica     Adventure       NaN
# 16717               Spirits & Spells      Platform       NaN
# 16718            Winning Post 8 2016    Simulation       NaN
#
# [16719 rows x 3 columns]

# %%
#14. Change User_Score data type to float and display all columns datatypes.
print("14. datatypes after changing user score datatype to float:")
video_games['User_Score']=video_games['User_Score'].astype(float)
video_games.dtypes
# Out:
# 14. datatypes after changing user score datatype to float:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#15. which developer has made how much sales in USD globally
print("15. developer's global sales:")
developers_global_sales=video_games.groupby('Developer')['Global_Sales'].sum()
developers_global_sales
# Out:
# 15. developer's global sales:
# Developer
# 10tacle Studios                          0.16
# 10tacle Studios, Fusionsphere Systems    0.11
# 1C, 1C Company                           0.03
# 1C, Ino-Co, 1C Company                   0.05
# 1C, Various, 1C Company                  0.01
#                                          ...
# odenis studio                            0.09
# oeFun                                    0.02
# puzzle.tv                                0.12
# syn Sophia                               3.31
# zSlide                                   0.03
# Name: Global_Sales, Length: 1696, dtype: float64

# %%
#16. remove all null values from User_Score and print those values to check
print("16. user_score values after removing null values:")
video_games.dropna(subset=['User_Score'],inplace=True)
video_games['User_Score']
# Out:
# 16. user_score values after removing null values:
# 0        8.0
# 2        8.3
# 3        8.0
# 6        8.5
# 7        6.6
#         ...
# 16685    8.1
# 16696    7.6
# 16700    5.8
# 16706    7.2
# 16709    5.8
# Name: User_Score, Length: 7590, dtype: float64

# %% [markdown]
# # 17. plot the histogram chart with x=User_Score and y-Developer
# import seaborn as sns
# print("17. Histogram of User_Score (grouped by developer:")
# top_developers=video_games['Developer'].value_counts().nlargest(5).index
# filtered_games=video_games[video_games['Developer'].isin(top_developers)]
# mplt.figure(figsize=(12,8))
# sns.histplot(data=filtered_games,x='User_Score',hue='Developer',kde=True)
# mplt.title('Distribution of user scores by top 5 developers')
# mplt.xlabel('User Score')
# mplt.ylabel('Developer')
# mplt.show()

# %%
# 18. Display all video games.
print("all videol games:")
print(video_games['Name'].unique())
# Out:
# all videol games:
# ['Wii Sports' 'Mario Kart Wii' 'Wii Sports Resort' ... 'Breach'
#  'STORM: Frontline Nation' '15 Days']

# %%
# 19. update NA_SALES with +5: (mapwith lambda)
#showing visual is extra.
print("19. NA_Sales afer adding 5:")
video_games['NA_Sales']=video_games['NA_Sales'].map(lambda x: x + 5 if pd.notna(x) else x)
print(video_games['NA_Sales'])
mplt.figure(figsize=(12,6))
sns.histplot(video_games['NA_Sales'])
mplt.title('Distribution of NA_Sales')
mplt.show()
# Out:
# 19. NA_Sales afer adding 5:
# 0        51.36
# 2        25.68
# 3        25.61
# 6        21.28
# 7        23.96
#          ...
# 16685    10.00
# 16696    10.00
# 16700    10.01
# 16706    10.00
# 16709    10.00
# Name: NA_Sales, Length: 7590, dtype: float64

# %%
#20. Display which Genre has many games.
print("20. Number of games per Genre:")
all_games=video_games.groupby('Genre')['Genre'].count()
print(all_games)
# Out:
# 20. Number of games per Genre:
# Genre
# Action          1830
# Adventure        300
# Fighting         399
# Misc             439
# Platform         428
# Puzzle           128
# Racing           641
# Role-Playing     743
# Shooter          924
# Simulation       344
# Sports          1103
# Strategy         311
# Name: Genre, dtype: int64

# %%
#21. Create a bar char for all games (Genre Distribution)
print("21. Bar chart of games by Genre:")
mplt.figure(figsize=(12,6))
all_games.plot(kind='bar')
mplt.title("Number of Games per Genre:")
mplt.xlabel('Genre')
mplt.ylabel('Number of games')
mplt.show()
# Out:
# 21. Bar chart of games by Genre:

# %%
#22. which developer has most games sold: top 20 developers 
print(" 22. top 20 most sold games by developers:\n")
top_20_developers=video_games.groupby('Developer')['Global_Sales'].sum().nlargest(20)
print(top_20_developers)
# Out:
#  22. top 20 most sold games by developers:
#
# Developer
# Nintendo                   529.90
# EA Sports                  170.43
# EA Canada                  137.65
# Rockstar North             119.47
# Capcom                     115.29
# Ubisoft                    112.63
# Ubisoft Montreal           107.26
# Treyarch                   103.00
# EA Tiburon                  91.30
# Infinity Ward               77.58
# Traveller's Tales           74.09
# Visual Concepts             69.72
# Polyphony Digital           65.20
# Konami                      63.87
# Namco                       61.78
# Neversoft Entertainment     61.17
# Electronic Arts             58.23
# SquareSoft                  54.65
# Vicarious Visions           53.22
# EA DICE                     51.01
# Name: Global_Sales, dtype: float64

# %%
#23. plot the bar chart for the above top 20 developers
print("23. bar chart for top 20 developers:")
mplt.figure(figsize=(14,8))
top_20_developers.plot(kind='bar')
mplt.title('top 20 developers by Global sales')
mplt.xlabel('Developer')
mplt.ylabel('Global Sales')
mplt.show()
# Out:
# 23. bar chart for top 20 developers:
